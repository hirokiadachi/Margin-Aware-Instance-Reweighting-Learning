# %%
# %run -i main.py --checkpoint ./checkpoint/cifar10/resnet18/trades --config_file configs/trades/config_resnet.yml --gpu 0,1,2,3
# Out:
# Namespace(checkpoint='./checkpoint/cifar10/resnet18/trades', config_file='configs/trades/config_resnet.yml', gpu='0,1,2,3')
# Files already downloaded and verified
# Files already downloaded and verified
# 0 epoch [0/391] | loss: 12.8245 (avg: 0.1002) | acc: 0.0938 (avg: 0.0938)
# 0 epoch [100/391] | loss: 2.2831 (avg: 0.0199) | acc: 0.1875 (avg: 0.1925)
# 0 epoch [200/391] | loss: 2.0779 (avg: 0.0185) | acc: 0.2891 (avg: 0.2233)
# 0 epoch [300/391] | loss: 2.0699 (avg: 0.0178) | acc: 0.2891 (avg: 0.2408)
# Validation | nat acc: 0.3163 | adv acc: 0.1953
# Current model achieved the best accuracy, so saved as the best model.
# 1 epoch [0/391] | loss: 2.0384 (avg: 0.0159) | acc: 0.2656 (avg: 0.2656)
# 1 epoch [100/391] | loss: 2.0025 (avg: 0.0159) | acc: 0.3438 (avg: 0.3144)
# 1 epoch [200/391] | loss: 1.9437 (avg: 0.0157) | acc: 0.3203 (avg: 0.3291)
# 1 epoch [300/391] | loss: 1.9873 (avg: 0.0156) | acc: 0.2891 (avg: 0.3323)
# Validation | nat acc: 0.3981 | adv acc: 0.2189
# ...
